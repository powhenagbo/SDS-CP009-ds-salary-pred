# %% [markdown]
# <a href="https://colab.research.google.com/github/powhenagbo/SDS-CP009-ds-salary-pred/blob/main/Copy_of_Paul_Notebook.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.impute import SimpleImputer
import re

# %%
# Load the dataset
df = pd.read_csv('salaries.csv')

# %%
df.head()
# Out:
#                          Company  Company Score  \
# 0                       ViewSoft            4.8
# 1                        Workiva            4.3
# 2     Garmin International, Inc.            3.9
# 3                       Snapchat            3.5
# 4  Vitesco Technologies Group AG            3.1
#
#                                            Job Title         Location Date  \
# 0                                  Software Engineer     Manassas, VA   8d
# 1                          Software Support Engineer           Remote   2d
# 2                               C# Software Engineer         Cary, NC   2d
# 3  Software Engineer, Fullstack, 1+ Years of Expe...  Los Angeles, CA   2d
# 4                                  Software Engineer       Seguin, TX   2d
#
#                           Salary
# 0   $68K - $94K (Glassdoor est.)
# 1   $61K - $104K (Employer est.)
# 2  $95K - $118K (Glassdoor est.)
# 3   $97K - $145K (Employer est.)
# 4  $85K - $108K (Glassdoor est.)

# %%
mv=df.isnull().sum()
mv
# Out:
# Company            2
# Company Score     81
# Job Title          0
# Location          13
# Date               0
# Salary           106
# dtype: int64

# %%
df2 = df[df.Company.notna()]
df2 = df[df['Company Score'].notna()]
df2 = df[df.Location.notna()]
df2 = df[df.Salary.notna()]
df2
# Out:
#                            Company  Company Score  \
# 0                         ViewSoft            4.8
# 1                          Workiva            4.3
# 2       Garmin International, Inc.            3.9
# 3                         Snapchat            3.5
# 4    Vitesco Technologies Group AG            3.1
# ..                             ...            ...
# 759                         OpenAI            3.1
# 760                     NCR Atleos            3.9
# 761  Electronic Warfare Associates            3.8
# 762                   BillGO, Inc.            3.3
# 763                        Genesys            3.6
#
#                                              Job Title           Location  \
# 0                                    Software Engineer       Manassas, VA
# 1                            Software Support Engineer             Remote
# 2                                 C# Software Engineer           Cary, NC
# 3    Software Engineer, Fullstack, 1+ Years of Expe...    Los Angeles, CA
# 4                                    Software Engineer         Seguin, TX
# ..                                                 ...                ...
# 759                   Apprentice ETL Software Engineer       Elkridge, MD
# 760  Software Engineer, Tool & Infrastructure, Reli...      Palo Alto, CA
# 761        Software Engineer, Engineering Acceleration  San Francisco, CA
# 762                  ATM Software Engineer (Level III)         Frisco, TX
# 763                                  Software Engineer   Mount Laurel, NJ
#
#      Date                         Salary
# 0      8d   $68K - $94K (Glassdoor est.)
# 1      2d   $61K - $104K (Employer est.)
# 2      2d  $95K - $118K (Glassdoor est.)
# 3      2d   $97K - $145K (Employer est.)
# 4      2d  $85K - $108K (Glassdoor est.)
# ..    ...                            ...
# 759  30d+  $160K - $385K (Employer est.)
# 760    1d          $222K (Employer est.)
# 761    5d  $82K - $118K (Glassdoor est.)
# 762  30d+  $69K - $107K (Glassdoor est.)
# 763  30d+   $95K - $143K (Employer est.)
#
# [764 rows x 6 columns]

# %%
len(df2.Company.unique())
# Out:
# 587

# %%
#now we'll gonna rid of the "(Glassdoor est)" thing in salary estimate col
salary = df2['Salary'].apply(lambda x: x.split('(')[0])
salary
# Out:
# 0        $68K - $94K
# 1       $61K - $104K
# 2       $95K - $118K
# 3       $97K - $145K
# 4       $85K - $108K
#             ...
# 759    $160K - $385K
# 760            $222K
# 761     $82K - $118K
# 762     $69K - $107K
# 763     $95K - $143K
# Name: Salary, Length: 764, dtype: object

# %%
#now we'll gonna replace $ sign and K in salary estimate col
dollarK = salary.apply(lambda x: x.replace('K','').replace('$',''))
dollarK
# Out:
# 0        68 - 94
# 1       61 - 104
# 2       95 - 118
# 3       97 - 145
# 4       85 - 108
#           ...
# 759    160 - 385
# 760          222
# 761     82 - 118
# 762     69 - 107
# 763     95 - 143
# Name: Salary, Length: 764, dtype: object

# %%
#there is per hour statement written on sal est so we'll gonna make another col for that
df2['hourly'] = df2['Salary'].apply(lambda x: 1 if 'per hour' in x.lower() else 0)
df2
# Out:
# <ipython-input-9-fb083b97e71c>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2['hourly'] = df2['Salary'].apply(lambda x: 1 if 'per hour' in x.lower() else 0)
#                            Company  Company Score  \
# 0                         ViewSoft            4.8
# 1                          Workiva            4.3
# 2       Garmin International, Inc.            3.9
# 3                         Snapchat            3.5
# 4    Vitesco Technologies Group AG            3.1
# ..                             ...            ...
# 759                         OpenAI            3.1
# 760                     NCR Atleos            3.9
# 761  Electronic Warfare Associates            3.8
# 762                   BillGO, Inc.            3.3
# 763                        Genesys            3.6
#
#                                              Job Title           Location  \
# 0                                    Software Engineer       Manassas, VA
# 1                            Software Support Engineer             Remote
# 2                                 C# Software Engineer           Cary, NC
# 3    Software Engineer, Fullstack, 1+ Years of Expe...    Los Angeles, CA
# 4                                    Software Engineer         Seguin, TX
# ..                                                 ...                ...
# 759                   Apprentice ETL Software Engineer       Elkridge, MD
# 760  Software Engineer, Tool & Infrastructure, Reli...      Palo Alto, CA
# 761        Software Engineer, Engineering Acceleration  San Francisco, CA
# 762                  ATM Software Engineer (Level III)         Frisco, TX
# 763                                  Software Engineer   Mount Laurel, NJ
#
#      Date                         Salary  hourly
# 0      8d   $68K - $94K (Glassdoor est.)       0
# 1      2d   $61K - $104K (Employer est.)       0
# 2      2d  $95K - $118K (Glassdoor est.)       0
# 3      2d   $97K - $145K (Employer est.)       0
# 4      2d  $85K - $108K (Glassdoor est.)       0
# ..    ...                            ...     ...
# 759  30d+  $160K - $385K (Employer est.)       0
# 760    1d          $222K (Employer est.)       0
# 761    5d  $82K - $118K (Glassdoor est.)       0
# 762  30d+  $69K - $107K (Glassdoor est.)       0
# 763  30d+   $95K - $143K (Employer est.)       0
#
# [764 rows x 7 columns]

# %%
#so there is also this thing written on that sal est col and we'll gonna make diff col for that
df2['source'] = df2['Salary'].apply(lambda x: 1 if 'employer provided salary:' in x.lower() else 0)
df2
# Out:
# <ipython-input-10-ea9e9fbf89bb>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2['source'] = df2['Salary'].apply(lambda x: 1 if 'employer provided salary:' in x.lower() else 0)
#                            Company  Company Score  \
# 0                         ViewSoft            4.8
# 1                          Workiva            4.3
# 2       Garmin International, Inc.            3.9
# 3                         Snapchat            3.5
# 4    Vitesco Technologies Group AG            3.1
# ..                             ...            ...
# 759                         OpenAI            3.1
# 760                     NCR Atleos            3.9
# 761  Electronic Warfare Associates            3.8
# 762                   BillGO, Inc.            3.3
# 763                        Genesys            3.6
#
#                                              Job Title           Location  \
# 0                                    Software Engineer       Manassas, VA
# 1                            Software Support Engineer             Remote
# 2                                 C# Software Engineer           Cary, NC
# 3    Software Engineer, Fullstack, 1+ Years of Expe...    Los Angeles, CA
# 4                                    Software Engineer         Seguin, TX
# ..                                                 ...                ...
# 759                   Apprentice ETL Software Engineer       Elkridge, MD
# 760  Software Engineer, Tool & Infrastructure, Reli...      Palo Alto, CA
# 761        Software Engineer, Engineering Acceleration  San Francisco, CA
# 762                  ATM Software Engineer (Level III)         Frisco, TX
# 763                                  Software Engineer   Mount Laurel, NJ
#
#      Date                         Salary  hourly  source
# 0      8d   $68K - $94K (Glassdoor est.)       0       0
# 1      2d   $61K - $104K (Employer est.)       0       0
# 2      2d  $95K - $118K (Glassdoor est.)       0       0
# 3      2d   $97K - $145K (Employer est.)       0       0
# 4      2d  $85K - $108K (Glassdoor est.)       0       0
# ..    ...                            ...     ...     ...
# 759  30d+  $160K - $385K (Employer est.)       0       0
# 760    1d          $222K (Employer est.)       0       0
# 761    5d  $82K - $118K (Glassdoor est.)       0       0
# 762  30d+  $69K - $107K (Glassdoor est.)       0       0
# 763  30d+   $95K - $143K (Employer est.)       0       0
#
# [764 rows x 8 columns]

# %%
#now we'll gonna replace this statements with a blank in salary estimate col
remove_hr = dollarK.apply(lambda x: x.lower().replace('per hour','').replace('employer provided salary:',''))
remove_hr
# Out:
# 0        68 - 94
# 1       61 - 104
# 2       95 - 118
# 3       97 - 145
# 4       85 - 108
#           ...
# 759    160 - 385
# 760          222
# 761     82 - 118
# 762     69 - 107
# 763     95 - 143
# Name: Salary, Length: 764, dtype: object

# %%
# Function to clean and handle salary strings with potential issues
def clean_salary_string(salary_str):
    if isinstance(salary_str, str):
        # Remove unwanted characters like "Per Hour" or extra spaces
        salary_str = re.sub(r'[^\dK-]', '', salary_str)
        salary_parts = salary_str.split('-')

        if len(salary_parts) == 2:
            # Extract both min and max salary from the range
            min_salary = int(salary_parts[0].replace('K', '')) * 1000
            max_salary = int(salary_parts[1].replace('K', '')) * 1000
        elif len(salary_parts) == 1:
            # Only one value, assume it's both min and max
            min_salary = max_salary = int(salary_parts[0].replace('K', '')) * 1000
        else:
            min_salary = max_salary = None
    else:
        min_salary = max_salary = None

    return pd.Series([min_salary, max_salary])

# Apply the cleaning function
df2[['min_salary', 'max_salary']] =df2['Salary'].apply(clean_salary_string)

# Display the cleaned data with min_salary and max_salary
df2.head()
# Out:
# <ipython-input-12-ff4e451e839c>:23: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2[['min_salary', 'max_salary']] =df2['Salary'].apply(clean_salary_string)
# <ipython-input-12-ff4e451e839c>:23: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2[['min_salary', 'max_salary']] =df2['Salary'].apply(clean_salary_string)
#                          Company  Company Score  \
# 0                       ViewSoft            4.8
# 1                        Workiva            4.3
# 2     Garmin International, Inc.            3.9
# 3                       Snapchat            3.5
# 4  Vitesco Technologies Group AG            3.1
#
#                                            Job Title         Location Date  \
# 0                                  Software Engineer     Manassas, VA   8d
# 1                          Software Support Engineer           Remote   2d
# 2                               C# Software Engineer         Cary, NC   2d
# 3  Software Engineer, Fullstack, 1+ Years of Expe...  Los Angeles, CA   2d
# 4                                  Software Engineer       Seguin, TX   2d
#
#                           Salary  hourly  source  min_salary  max_salary
# 0   $68K - $94K (Glassdoor est.)       0       0       68000       94000
# 1   $61K - $104K (Employer est.)       0       0       61000      104000
# 2  $95K - $118K (Glassdoor est.)       0       0       95000      118000
# 3   $97K - $145K (Employer est.)       0       0       97000      145000
# 4  $85K - $108K (Glassdoor est.)       0       0       85000      108000

# %%
# Safely extract the state from the 'Location' column, handling NaN values
df2['job_state'] = df2['Location'].apply(lambda x: x.split(',')[1].strip() if isinstance(x, str) and ',' in x else 'Unknown')

# Display the first few rows to verify the change
df2.head()
# Out:
# <ipython-input-13-542dbc154c64>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2['job_state'] = df2['Location'].apply(lambda x: x.split(',')[1].strip() if isinstance(x, str) and ',' in x else 'Unknown')
#                          Company  Company Score  \
# 0                       ViewSoft            4.8
# 1                        Workiva            4.3
# 2     Garmin International, Inc.            3.9
# 3                       Snapchat            3.5
# 4  Vitesco Technologies Group AG            3.1
#
#                                            Job Title         Location Date  \
# 0                                  Software Engineer     Manassas, VA   8d
# 1                          Software Support Engineer           Remote   2d
# 2                               C# Software Engineer         Cary, NC   2d
# 3  Software Engineer, Fullstack, 1+ Years of Expe...  Los Angeles, CA   2d
# 4                                  Software Engineer       Seguin, TX   2d
#
#                           Salary  hourly  source  min_salary  max_salary  \
# 0   $68K - $94K (Glassdoor est.)       0       0       68000       94000
# 1   $61K - $104K (Employer est.)       0       0       61000      104000
# 2  $95K - $118K (Glassdoor est.)       0       0       95000      118000
# 3   $97K - $145K (Employer est.)       0       0       97000      145000
# 4  $85K - $108K (Glassdoor est.)       0       0       85000      108000
#
#   job_state
# 0        VA
# 1   Unknown
# 2        NC
# 3        CA
# 4        TX

# %%
df2.job_state.value_counts()
# Out:
# job_state
# Unknown    127
# CA         103
# MD          69
# WA          42
# TX          42
# VA          37
# MA          37
# FL          27
# NY          26
# GA          23
# IL          23
# CO          20
# MI          19
# NJ          19
# PA          17
# AZ          11
# OH          11
# WI          11
# NC          11
# DC          10
# MN           9
# CT           7
# UT           6
# OR           5
# KS           4
# ID           4
# AL           4
# IA           4
# DE           3
# VT           3
# MS           3
# IN           3
# OK           3
# SC           3
# KY           2
# RI           2
# NM           2
# AR           2
# PR           2
# NE           2
# NH           2
# TN           1
# MO           1
# WV           1
# HI           1
# Name: count, dtype: int64

# %%
#now we'll gonna see some few more columns, split them from salary estimate
df2['avg_salary'] = (df2.min_salary+df2.max_salary)/2
df2
# Out:
# <ipython-input-16-cb46d40f048f>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2['avg_salary'] = (df2.min_salary+df2.max_salary)/2
#                            Company  Company Score  \
# 0                         ViewSoft            4.8
# 1                          Workiva            4.3
# 2       Garmin International, Inc.            3.9
# 3                         Snapchat            3.5
# 4    Vitesco Technologies Group AG            3.1
# ..                             ...            ...
# 759                         OpenAI            3.1
# 760                     NCR Atleos            3.9
# 761  Electronic Warfare Associates            3.8
# 762                   BillGO, Inc.            3.3
# 763                        Genesys            3.6
#
#                                              Job Title           Location  \
# 0                                    Software Engineer       Manassas, VA
# 1                            Software Support Engineer             Remote
# 2                                 C# Software Engineer           Cary, NC
# 3    Software Engineer, Fullstack, 1+ Years of Expe...    Los Angeles, CA
# 4                                    Software Engineer         Seguin, TX
# ..                                                 ...                ...
# 759                   Apprentice ETL Software Engineer       Elkridge, MD
# 760  Software Engineer, Tool & Infrastructure, Reli...      Palo Alto, CA
# 761        Software Engineer, Engineering Acceleration  San Francisco, CA
# 762                  ATM Software Engineer (Level III)         Frisco, TX
# 763                                  Software Engineer   Mount Laurel, NJ
#
#      Date                         Salary  hourly  source  min_salary  \
# 0      8d   $68K - $94K (Glassdoor est.)       0       0       68000
# 1      2d   $61K - $104K (Employer est.)       0       0       61000
# 2      2d  $95K - $118K (Glassdoor est.)       0       0       95000
# 3      2d   $97K - $145K (Employer est.)       0       0       97000
# 4      2d  $85K - $108K (Glassdoor est.)       0       0       85000
# ..    ...                            ...     ...     ...         ...
# 759  30d+  $160K - $385K (Employer est.)       0       0      160000
# 760    1d          $222K (Employer est.)       0       0      222000
# 761    5d  $82K - $118K (Glassdoor est.)       0       0       82000
# 762  30d+  $69K - $107K (Glassdoor est.)       0       0       69000
# 763  30d+   $95K - $143K (Employer est.)       0       0       95000
#
#      max_salary job_state  avg_salary
# 0         94000        VA     81000.0
# 1        104000   Unknown     82500.0
# 2        118000        NC    106500.0
# 3        145000        CA    121000.0
# 4        108000        TX     96500.0
# ..          ...       ...         ...
# 759      385000        MD    272500.0
# 760      222000        CA    222000.0
# 761      118000        CA    100000.0
# 762      107000        TX     88000.0
# 763      143000        NJ    119000.0
#
# [764 rows x 12 columns]

# %%
df2.columns
# Out:
# Index(['Company', 'Company Score', 'Job Title', 'Location', 'Date', 'Salary',
#        'hourly', 'source', 'min_salary', 'max_salary', 'job_state',
#        'avg_salary'],
#       dtype='object')

# %%
df.describe()
# Out:
#        Company Score
# count     789.000000
# mean        3.895311
# std         0.524952
# min         1.000000
# 25%         3.600000
# 50%         3.900000
# 75%         4.200000
# max         5.000000

# %%
df['Company Score'].value_counts()
# Out:
# Company Score
# 4.1    83
# 3.9    72
# 3.8    68
# 4.0    62
# 3.7    61
# 3.5    58
# 4.2    54
# 3.6    41
# 3.4    37
# 4.4    33
# 5.0    28
# 3.1    25
# 4.3    21
# 4.5    20
# 4.6    18
# 4.8    18
# 3.3    18
# 4.7    15
# 3.0    13
# 3.2    13
# 4.9     7
# 2.9     5
# 2.5     5
# 2.7     4
# 2.4     3
# 2.0     2
# 2.3     2
# 2.6     1
# 2.8     1
# 1.0     1
# Name: count, dtype: int64

# %%
df['Salary'].value_counts()
# Out:
# Salary
# $120K - $150K (Employer est.)               5
# $129K - $224K (Employer est.)               5
# $120K - $140K (Employer est.)               4
# $155K - $221K (Employer est.)               3
# $160K - $385K (Employer est.)               3
#                                            ..
# $125K - $200K (Employer est.)               1
# $168K (Employer est.)                       1
# $110K - $143K (Glassdoor est.)              1
# $80.00 - $85.00 Per Hour (Employer est.)    1
# $95K - $143K (Employer est.)                1
# Name: count, Length: 680, dtype: int64

# %%
df.describe()
# Out:
#        Company Score
# count     789.000000
# mean        3.895311
# std         0.524952
# min         1.000000
# 25%         3.600000
# 50%         3.900000
# 75%         4.200000
# max         5.000000

# %%
# Ensure the value is a string and apply the split, handling non-string values (e.g., floats)
sal = df['Salary'].apply(lambda x: str(x).split('(')[0] if isinstance(x, str) else x)

# Display the result
sal.head()
# Out:
# 0     $68K - $94K
# 1    $61K - $104K
# 2    $95K - $118K
# 3    $97K - $145K
# 4    $85K - $108K
# Name: Salary, dtype: object

# %%
remove_k=sal.apply(lambda x: re.sub(r'[^\d.-]', '', str(x)))
remove_k
# Out:
# 0       68-94
# 1      61-104
# 2      95-118
# 3      97-145
# 4      85-108
#         ...
# 865
# 866
# 867
# 868
# 869
# Name: Salary, Length: 870, dtype: object

# %%
df['min_salary']=remove_k.apply(lambda x: int(x.split('-')[0]))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-9-ea7c7ad985a0> in <cell line: 1>()
# ----> 1 df['min_salary']=remove_k.apply(lambda x: int(x.split('-')[0]))
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/series.py in apply(self, func, convert_dtype, args, by_row, **kwargs)
#    4922             args=args,
#    4923             kwargs=kwargs,
# -> 4924         ).apply()
#    4925
#    4926     def _reindex_indexer(
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/apply.py in apply(self)
#    1425
#    1426         # self.func is Callable
# -> 1427         return self.apply_standard()
#    1428
#    1429     def agg(self):
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/apply.py in apply_standard(self)
#    1505         #  Categorical (GH51645).
#    1506         action = "ignore" if isinstance(obj.dtype, CategoricalDtype) else None
# -> 1507         mapped = obj._map_values(
#    1508             mapper=curried, na_action=action, convert=self.convert_dtype
#    1509         )
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/base.py in _map_values(self, mapper, na_action, convert)
#     919             return arr.map(mapper, na_action=na_action)
#     920
# --> 921         return algorithms.map_array(arr, mapper, na_action=na_action, convert=convert)
#     922
#     923     @final
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/algorithms.py in map_array(arr, mapper, na_action, convert)
#    1741     values = arr.astype(object, copy=False)
#    1742     if na_action is None:
# -> 1743         return lib.map_infer(values, mapper, convert=convert)
#    1744     else:
#    1745         return lib.map_infer_mask(
#
# lib.pyx in pandas._libs.lib.map_infer()
#
# <ipython-input-9-ea7c7ad985a0> in <lambda>(x)
# ----> 1 df['min_salary']=remove_k.apply(lambda x: int(x.split('-')[0]))
#
# ValueError: invalid literal for int() with base 10: '80.00'

# %%
remove_k=sal.apply(lambda x:x.replace('K','').replace('$','')if isinstance(x, str) else x)

remove_k
# Out:
# 0       68 - 94
# 1      61 - 104
# 2      95 - 118
# 3      97 - 145
# 4      85 - 108
#          ...
# 865          NaN
# 866          NaN
# 867          NaN
# 868          NaN
# 869          NaN
# Name: Salary, Length: 870, dtype: object

# %%
remove_k = sal.apply(lambda x: re.sub(r'[^\d.-]', '', str(x)))

# Extract the minimum salary by first converting to float and then to int
df['min_salary'] = remove_k.apply(lambda x: int(float(x.split('-')[0])) if '-' in x else int(float(x)))

# Display the result
df['min_salary']
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-19-6c9f7eb5c9bd> in <cell line: 4>()
#       2
#       3 # Extract the minimum salary by first converting to float and then to int
# ----> 4 df['min_salary'] = remove_k.apply(lambda x: int(float(x.split('-')[0])) if '-' in x else int(float(x)))
#       5
#       6 # Display the result
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/series.py in apply(self, func, convert_dtype, args, by_row, **kwargs)
#    4922             args=args,
#    4923             kwargs=kwargs,
# -> 4924         ).apply()
#    4925
#    4926     def _reindex_indexer(
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/apply.py in apply(self)
#    1425
#    1426         # self.func is Callable
# -> 1427         return self.apply_standard()
#    1428
#    1429     def agg(self):
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/apply.py in apply_standard(self)
#    1505         #  Categorical (GH51645).
#    1506         action = "ignore" if isinstance(obj.dtype, CategoricalDtype) else None
# -> 1507         mapped = obj._map_values(
#    1508             mapper=curried, na_action=action, convert=self.convert_dtype
#    1509         )
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/base.py in _map_values(self, mapper, na_action, convert)
#     919             return arr.map(mapper, na_action=na_action)
#     920
# --> 921         return algorithms.map_array(arr, mapper, na_action=na_action, convert=convert)
#     922
#     923     @final
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/algorithms.py in map_array(arr, mapper, na_action, convert)
#    1741     values = arr.astype(object, copy=False)
#    1742     if na_action is None:
# -> 1743         return lib.map_infer(values, mapper, convert=convert)
#    1744     else:
#    1745         return lib.map_infer_mask(
#
# lib.pyx in pandas._libs.lib.map_infer()
#
# <ipython-input-19-6c9f7eb5c9bd> in <lambda>(x)
#       2
#       3 # Extract the minimum salary by first converting to float and then to int
# ----> 4 df['min_salary'] = remove_k.apply(lambda x: int(float(x.split('-')[0])) if '-' in x else int(float(x)))
#       5
#       6 # Display the result
#
# ValueError: could not convert string to float: ''

# %%
# Assuming df is your DataFrame, and you want to remove 'K' and '$' from the 'Salary' column
remove_k = df['Salary'].apply(lambda x: str(x).replace('K','').replace('$',''))

# Display the result
print(remove_k.head())
# Out:
# 0     68 - 94 (Glassdoor est.)
# 1     61 - 104 (Employer est.)
# 2    95 - 118 (Glassdoor est.)
# 3     97 - 145 (Employer est.)
# 4    85 - 108 (Glassdoor est.)
# Name: Salary, dtype: object

# %%
import re

# Remove non-numeric characters except for '-' and extract the salary range
remove_k_cleaned = remove_k.apply(lambda x: re.sub(r'[^\d-]', '', x))

# Extract the minimum salary from the cleaned string
df['min_salary'] = remove_k_cleaned.apply(lambda x: int(x.split('-')[0]) if '-' in x else int(x))

# Display the result
print(df[['Salary', 'min_salary']].head())
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-24-2a028b47d88d> in <cell line: 7>()
#       5
#       6 # Extract the minimum salary from the cleaned string
# ----> 7 df['min_salary'] = remove_k_cleaned.apply(lambda x: int(x.split('-')[0]) if '-' in x else int(x))
#       8
#       9 # Display the result
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/series.py in apply(self, func, convert_dtype, args, by_row, **kwargs)
#    4922             args=args,
#    4923             kwargs=kwargs,
# -> 4924         ).apply()
#    4925
#    4926     def _reindex_indexer(
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/apply.py in apply(self)
#    1425
#    1426         # self.func is Callable
# -> 1427         return self.apply_standard()
#    1428
#    1429     def agg(self):
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/apply.py in apply_standard(self)
#    1505         #  Categorical (GH51645).
#    1506         action = "ignore" if isinstance(obj.dtype, CategoricalDtype) else None
# -> 1507         mapped = obj._map_values(
#    1508             mapper=curried, na_action=action, convert=self.convert_dtype
#    1509         )
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/base.py in _map_values(self, mapper, na_action, convert)
#     919             return arr.map(mapper, na_action=na_action)
#     920
# --> 921         return algorithms.map_array(arr, mapper, na_action=na_action, convert=convert)
#     922
#     923     @final
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/algorithms.py in map_array(arr, mapper, na_action, convert)
#    1741     values = arr.astype(object, copy=False)
#    1742     if na_action is None:
# -> 1743         return lib.map_infer(values, mapper, convert=convert)
#    1744     else:
#    1745         return lib.map_infer_mask(
#
# lib.pyx in pandas._libs.lib.map_infer()
#
# <ipython-input-24-2a028b47d88d> in <lambda>(x)
#       5
#       6 # Extract the minimum salary from the cleaned string
# ----> 7 df['min_salary'] = remove_k_cleaned.apply(lambda x: int(x.split('-')[0]) if '-' in x else int(x))
#       8
#       9 # Display the result
#
# ValueError: invalid literal for int() with base 10: ''

# %%
df.shape
# Out:
# (870, 6)

# %%
# Function to clean the salary column and extract min and max salary values
def extract_salary_range(salary_str):
    # Use regex to find salary range in the format (e.g., "$68K - $94K")
    salary_range = re.findall(r'(\d+K)', salary_str)

    # If two values are found, assign min and max salary
    if len(salary_range) == 2:
        min_salary = int(salary_range[0].replace('K', '')) * 1000
        max_salary = int(salary_range[1].replace('K', '')) * 1000
        return (min_salary + max_salary) / 2  # Return the average salary
    return None

# Apply the function to the 'Salary' column and create a new column for average salary
df['Average Salary'] = df['Salary'].apply(extract_salary_range)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-4-13981b84f8d7> in <cell line: 14>()
#      12
#      13 # Apply the function to the 'Salary' column and create a new column for average salary
# ---> 14 df['Average Salary'] = df['Salary'].apply(extract_salary_range)
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/series.py in apply(self, func, convert_dtype, args, by_row, **kwargs)
#    4922             args=args,
#    4923             kwargs=kwargs,
# -> 4924         ).apply()
#    4925
#    4926     def _reindex_indexer(
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/apply.py in apply(self)
#    1425
#    1426         # self.func is Callable
# -> 1427         return self.apply_standard()
#    1428
#    1429     def agg(self):
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/apply.py in apply_standard(self)
#    1505         #  Categorical (GH51645).
#    1506         action = "ignore" if isinstance(obj.dtype, CategoricalDtype) else None
# -> 1507         mapped = obj._map_values(
#    1508             mapper=curried, na_action=action, convert=self.convert_dtype
#    1509         )
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/base.py in _map_values(self, mapper, na_action, convert)
#     919             return arr.map(mapper, na_action=na_action)
#     920
# --> 921         return algorithms.map_array(arr, mapper, na_action=na_action, convert=convert)
#     922
#     923     @final
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/algorithms.py in map_array(arr, mapper, na_action, convert)
#    1741     values = arr.astype(object, copy=False)
#    1742     if na_action is None:
# -> 1743         return lib.map_infer(values, mapper, convert=convert)
#    1744     else:
#    1745         return lib.map_infer_mask(
#
# lib.pyx in pandas._libs.lib.map_infer()
#
# <ipython-input-4-13981b84f8d7> in extract_salary_range(salary_str)
#       2 def extract_salary_range(salary_str):
#       3     # Use regex to find salary range in the format (e.g., "$68K - $94K")
# ----> 4     salary_range = re.findall(r'(\d+K)', salary_str)
#       5
#       6     # If two values are found, assign min and max salary
#
# /usr/lib/python3.10/re.py in findall(pattern, string, flags)
#     238
#     239     Empty matches are included in the result."""
# --> 240     return _compile(pattern, flags).findall(string)
#     241
#     242 def finditer(pattern, string, flags=0):
#
# TypeError: expected string or bytes-like object

# %%
# Now let's check for missing values in the new 'Average Salary' column

missing_salaries = df['Average Salary'].isnull().sum()

# Display the number of missing salaries

missing_salaries
# Out:
# 148

# %%
# Create an instance of SimpleImputer for numerical data
imputer_numeric = SimpleImputer(strategy='mean')

# Apply it to the 'Company Score' (numerical column) to fill missing values with the mean
df[['Company Score']] = imputer_numeric.fit_transform(df[['Company Score']])

# For categorical columns (like 'Company', 'Location'), use the most frequent value to fill missing data
imputer_categorical = SimpleImputer(strategy='most_frequent')

# Apply it to the 'Company' and 'Location' columns
df[['Company', 'Location']] = imputer_categorical.fit_transform(df[['Company', 'Location']])


# Create an instance of SimpleImputer for numerical data (strategy = median)
imputer = SimpleImputer(strategy='median')

# Apply it to the 'Average Salary' column to fill missing values with the median
df[['Average Salary']] = imputer.fit_transform(df[['Average Salary']])

# Check for any remaining missing values in the dataset
df.isnull().sum()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-5-1863a2f0a586> in <cell line: 18>()
#      16
#      17 # Apply it to the 'Average Salary' column to fill missing values with the median
# ---> 18 df[['Average Salary']] = imputer.fit_transform(df[['Average Salary']])
#      19
#      20 # Check for any remaining missing values in the dataset
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/frame.py in __getitem__(self, key)
#    4106             if is_iterator(key):
#    4107                 key = list(key)
# -> 4108             indexer = self.columns._get_indexer_strict(key, "columns")[1]
#    4109
#    4110         # take() does not accept boolean indexers
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/indexes/base.py in _get_indexer_strict(self, key, axis_name)
#    6198             keyarr, indexer, new_indexer = self._reindex_non_unique(keyarr)
#    6199
# -> 6200         self._raise_if_missing(keyarr, indexer, axis_name)
#    6201
#    6202         keyarr = self.take(indexer)
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/indexes/base.py in _raise_if_missing(self, key, indexer, axis_name)
#    6247         if nmissing:
#    6248             if nmissing == len(indexer):
# -> 6249                 raise KeyError(f"None of [{key}] are in the [{axis_name}]")
#    6250
#    6251             not_found = list(ensure_index(key)[missing_mask.nonzero()[0]].unique())
#
# KeyError: "None of [Index(['Average Salary'], dtype='object')] are in the [columns]"

# %%
df.head()
# Out:
#                          Company  Company Score  \
# 0                       ViewSoft            4.8
# 1                        Workiva            4.3
# 2     Garmin International, Inc.            3.9
# 3                       Snapchat            3.5
# 4  Vitesco Technologies Group AG            3.1
#
#                                            Job Title         Location Date  \
# 0                                  Software Engineer     Manassas, VA   8d
# 1                          Software Support Engineer           Remote   2d
# 2                               C# Software Engineer         Cary, NC   2d
# 3  Software Engineer, Fullstack, 1+ Years of Expe...  Los Angeles, CA   2d
# 4                                  Software Engineer       Seguin, TX   2d
#
#                           Salary  Min Salary  Max Salary  Average Salary
# 0   $68K - $94K (Glassdoor est.)     68000.0     94000.0         81000.0
# 1   $61K - $104K (Employer est.)     61000.0    104000.0         82500.0
# 2  $95K - $118K (Glassdoor est.)     95000.0    118000.0        106500.0
# 3   $97K - $145K (Employer est.)     97000.0    145000.0        121000.0
# 4  $85K - $108K (Glassdoor est.)     85000.0    108000.0         96500.0

# %%
# the 'Salary' column has been drop now that min and max salaries are extracted
df2 = df.drop(columns=['Salary'])

# show the new data without the Salary column
df2.head(20)
# Out:
#                           Company  Company Score  \
# 0                        ViewSoft            4.8
# 1                         Workiva            4.3
# 2      Garmin International, Inc.            3.9
# 3                        Snapchat            3.5
# 4   Vitesco Technologies Group AG            3.1
# 5                         Spotify            3.9
# 6                           Infor            4.0
# 7           Amerisoft Corporation            5.0
# 8                           WHOOP            3.3
# 9                             PFF            4.2
# 10                     Salesforce            4.1
# 11      HealthMine Services, Inc.            3.8
# 12                      Honeywell            4.1
# 13                     Legrand AV            3.7
# 14                   Athenahealth            4.0
# 15                           Amex            4.1
# 16                   SOFT LABS NA            5.0
# 17                       Snapchat            3.5
# 18                          Hertz            3.2
# 19                       Megaport            3.4
#
#                                             Job Title                Location  \
# 0                                   Software Engineer            Manassas, VA
# 1                           Software Support Engineer                  Remote
# 2                                C# Software Engineer                Cary, NC
# 3   Software Engineer, Fullstack, 1+ Years of Expe...         Los Angeles, CA
# 4                                   Software Engineer              Seguin, TX
# 5                                 Backend Engineer II            New York, NY
# 6                         Associate Software Engineer          Alpharetta, GA
# 7                                 Software Developers    Farmington Hills, MI
# 8              Software Engineer II (Backend, Health)              Boston, MA
# 9                               Sr. Software Engineer                  Remote
# 10                              MTS Software Engineer       San Francisco, CA
# 11                                  Software Engineer                  Remote
# 12                                Software Engineer I           Aguadilla, PR
# 13                                  Software Engineer  Minneapolis-Saint Paul
# 14     Software Engineer, athenaCollector – RCM Rules              Boston, MA
# 15                                      Java Engineer          Plantation, FL
# 16    Entry Level to Senior Level Software Developers        Northborough, MA
# 17                             Software Engineer, C++         Los Angeles, CA
# 18                                  Software Engineer             Seattle, WA
# 19                         Frontend Software Engineer           United States
#
#     Date  Min Salary  Max Salary  Average Salary
# 0     8d     68000.0     94000.0         81000.0
# 1     2d     61000.0    104000.0         82500.0
# 2     2d     95000.0    118000.0        106500.0
# 3     2d     97000.0    145000.0        121000.0
# 4     2d     85000.0    108000.0         96500.0
# 5     1d    123000.0    175000.0        149000.0
# 6     7d     77000.0     94000.0         85500.0
# 7   30d+     71000.0    100000.0         85500.0
# 8    10d     94000.0    148000.0        121000.0
# 9     1d    147000.0    189000.0        168000.0
# 10    5d     90000.0    113000.0        101500.0
# 11    1d     54000.0     79000.0         66500.0
# 12    2d     91000.0    135000.0        113000.0
# 13    2d     70000.0    135000.0        102500.0
# 14    2d    192000.0    288000.0        240000.0
# 15    6d    100000.0    125000.0        112500.0
# 16  30d+     85000.0    127000.0        106000.0
# 17    2d     69000.0    109000.0         89000.0
# 18    2d    124000.0    234000.0        179000.0
# 19    2d     84000.0    133000.0        108500.0

# %%
mv=df2.isnull().sum()
mv
# Out:
# Company           0
# Company Score     0
# Job Title         0
# Location          0
# Date              0
# Min Salary        0
# Max Salary        0
# Average Salary    0
# dtype: int64

# %%
df2 = df2.drop_duplicates()

# %%
df2.to_csv('IT salaries_cleaned new.csv', index=False)

# %%
df3=pd.read_csv('IT salaries_cleaned new.csv')

# %%
# X: All columns except the last one (Average Salary)
X = df3.iloc[:, :-1].values

# y: The last column (Average Salary)
y = df3.iloc[:, -1].values

print("Independent Variables (X):")
print(X)
# Out:
# Independent Variables (X):
# [['ViewSoft' 4.8 'Software Engineer' ... '8d' 68000.0 94000.0]
#  ['Workiva' 4.3 'Software Support Engineer' ... '2d' 61000.0 104000.0]
#  ['Garmin International, Inc.' 3.9 'C# Software Engineer' ... '2d'
#   95000.0 118000.0]
#  ...
#  ['Medtronic' 3.895310519645121 'Senior Software Engineer' ... '19d'
#   103481.9944598338 155217.4515235457]
#  ['CVS Health' 3.895310519645121 'Junior Python Developer' ... '2d'
#   103481.9944598338 155217.4515235457]
#  ['CVS Health' 3.895310519645121
#   'GUI Software Engineer II - Surgical Robotics' ... '10d'
#   103481.9944598338 155217.4515235457]]

# %%
print (y)
# Out:
# [ 81000.  82500. 106500. 121000.  96500. 149000.  85500.  85500. 121000.
#  168000. 101500.  66500. 113000. 102500. 240000. 112500. 106000.  89000.
#  179000. 108500. 117500.  68500.  81500. 153500. 137500. 133000. 113500.
#   93000. 160000. 111000. 129500. 122500. 134500.  96000. 150000.  64500.
#  154000. 101500. 150000.  89000. 188000. 138500.  91000. 135000. 106000.
